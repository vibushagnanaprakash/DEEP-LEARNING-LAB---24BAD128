# %%
#24BAD128 - VIBUSHA.G - EXP 2 - PART A
print("24BAD128 - VIBUSHA.G - EXP 2 - PART A")

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
# Out:
# 24BAD128 - VIBUSHA.G - EXP 2 - PART A

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def tanh(x):
    return np.tanh(x)

def relu(x):
    return np.maximum(0, x)

# %%
x = np.linspace(-10, 10, 1000)

sigmoid_values = sigmoid(x)
tanh_values = tanh(x)
relu_values = relu(x)

# %%
plt.figure(figsize=(12, 8))

plt.subplot(3, 1, 1)
plt.plot(x, sigmoid_values)
plt.title("Sigmoid Activation Function")
plt.xlabel("Input")
plt.ylabel("Output")
plt.grid()

plt.subplot(3, 1, 2)
plt.plot(x, tanh_values)
plt.title("Tanh Activation Function")
plt.xlabel("Input")
plt.ylabel("Output")
plt.grid()

plt.subplot(3, 1, 3)
plt.plot(x, relu_values)
plt.title("ReLU Activation Function")
plt.xlabel("Input")
plt.ylabel("Output")
plt.grid()

plt.tight_layout()
plt.show()

# %%
#EXP 2 - Part B
print("EXP 2 - Part B")

from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

print("Training data shape:", x_train.shape)
print("Testing data shape:", x_test.shape)
# Out:
# EXP 2 - Part B
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Training data shape: (60000, 784)
# Testing data shape: (10000, 784)

# %%
def create_model(activation_function):
    model = tf.keras.Sequential([
        tf.keras.layers.Input(shape=(784,)),
        tf.keras.layers.Dense(128, activation=activation_function),
        tf.keras.layers.Dense(64, activation=activation_function),
        tf.keras.layers.Dense(10, activation='softmax')
    ])

    model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# %%
sigmoid_model = create_model('sigmoid')

history_sigmoid = sigmoid_model.fit(
    x_train,
    y_train,
    epochs=20,
    batch_size=128,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7981 - loss: 0.9123 - val_accuracy: 0.9086 - val_loss: 0.3617
# Epoch 2/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9165 - loss: 0.3076 - val_accuracy: 0.9293 - val_loss: 0.2481
# Epoch 3/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9341 - loss: 0.2301 - val_accuracy: 0.9402 - val_loss: 0.2076
# Epoch 4/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9458 - loss: 0.1872 - val_accuracy: 0.9510 - val_loss: 0.1734
# Epoch 5/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9542 - loss: 0.1568 - val_accuracy: 0.9569 - val_loss: 0.1512
# Epoch 6/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9614 - loss: 0.1328 - val_accuracy: 0.9598 - val_loss: 0.1390
# Epoch 7/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9671 - loss: 0.1139 - val_accuracy: 0.9633 - val_loss: 0.1295
# Epoch 8/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9715 - loss: 0.0982 - val_accuracy: 0.9668 - val_loss: 0.1161
# Epoch 9/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9758 - loss: 0.0853 - val_accuracy: 0.9684 - val_loss: 0.1095
# Epoch 10/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9790 - loss: 0.0740 - val_accuracy: 0.9697 - val_loss: 0.1039
# Epoch 11/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9821 - loss: 0.0649 - val_accuracy: 0.9710 - val_loss: 0.0975
# Epoch 12/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9844 - loss: 0.0567 - val_accuracy: 0.9711 - val_loss: 0.0935
# Epoch 13/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9868 - loss: 0.0491 - val_accuracy: 0.9703 - val_loss: 0.0943
# Epoch 14/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9889 - loss: 0.0429 - val_accuracy: 0.9735 - val_loss: 0.0888
# Epoch 15/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9905 - loss: 0.0376 - val_accuracy: 0.9738 - val_loss: 0.0890
# Epoch 16/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9920 - loss: 0.0329 - val_accuracy: 0.9735 - val_loss: 0.0863
# Epoch 17/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9933 - loss: 0.0280 - val_accuracy: 0.9741 - val_loss: 0.0856
# Epoch 18/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9946 - loss: 0.0245 - val_accuracy: 0.9750 - val_loss: 0.0848
# Epoch 19/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9958 - loss: 0.0209 - val_accuracy: 0.9743 - val_loss: 0.0907
# Epoch 20/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9966 - loss: 0.0179 - val_accuracy: 0.9747 - val_loss: 0.0851

# %%
tanh_model = create_model('tanh')

history_tanh = tanh_model.fit(
    x_train,
    y_train,
    epochs=20,
    batch_size=128,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8955 - loss: 0.3800 - val_accuracy: 0.9383 - val_loss: 0.2191
# Epoch 2/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9475 - loss: 0.1841 - val_accuracy: 0.9529 - val_loss: 0.1647
# Epoch 3/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9615 - loss: 0.1328 - val_accuracy: 0.9612 - val_loss: 0.1390
# Epoch 4/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9704 - loss: 0.1015 - val_accuracy: 0.9653 - val_loss: 0.1179
# Epoch 5/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9760 - loss: 0.0806 - val_accuracy: 0.9696 - val_loss: 0.1073
# Epoch 6/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9812 - loss: 0.0631 - val_accuracy: 0.9687 - val_loss: 0.1049
# Epoch 7/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9851 - loss: 0.0511 - val_accuracy: 0.9694 - val_loss: 0.1025
# Epoch 8/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9883 - loss: 0.0411 - val_accuracy: 0.9728 - val_loss: 0.0917
# Epoch 9/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9916 - loss: 0.0316 - val_accuracy: 0.9734 - val_loss: 0.0918
# Epoch 10/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9929 - loss: 0.0257 - val_accuracy: 0.9740 - val_loss: 0.0871
# Epoch 11/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9948 - loss: 0.0207 - val_accuracy: 0.9747 - val_loss: 0.0874
# Epoch 12/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9967 - loss: 0.0156 - val_accuracy: 0.9743 - val_loss: 0.0928
# Epoch 13/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9974 - loss: 0.0126 - val_accuracy: 0.9725 - val_loss: 0.0999
# Epoch 14/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9979 - loss: 0.0109 - val_accuracy: 0.9749 - val_loss: 0.0932
# Epoch 15/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9986 - loss: 0.0079 - val_accuracy: 0.9747 - val_loss: 0.0992
# Epoch 16/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9987 - loss: 0.0069 - val_accuracy: 0.9750 - val_loss: 0.1001
# Epoch 17/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9990 - loss: 0.0060 - val_accuracy: 0.9753 - val_loss: 0.0966
# Epoch 18/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9995 - loss: 0.0042 - val_accuracy: 0.9768 - val_loss: 0.0973
# Epoch 19/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9983 - loss: 0.0068 - val_accuracy: 0.9758 - val_loss: 0.1031
# Epoch 20/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9997 - loss: 0.0028 - val_accuracy: 0.9763 - val_loss: 0.1031

# %%
relu_model = create_model('relu')

history_relu = relu_model.fit(
    x_train,
    y_train,
    epochs=20,
    batch_size=128,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8937 - loss: 0.3758 - val_accuracy: 0.9418 - val_loss: 0.1973
# Epoch 2/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9546 - loss: 0.1549 - val_accuracy: 0.9603 - val_loss: 0.1387
# Epoch 3/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9679 - loss: 0.1081 - val_accuracy: 0.9679 - val_loss: 0.1064
# Epoch 4/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9760 - loss: 0.0808 - val_accuracy: 0.9672 - val_loss: 0.1050
# Epoch 5/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9807 - loss: 0.0630 - val_accuracy: 0.9709 - val_loss: 0.0970
# Epoch 6/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9855 - loss: 0.0499 - val_accuracy: 0.9678 - val_loss: 0.1061
# Epoch 7/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9871 - loss: 0.0417 - val_accuracy: 0.9754 - val_loss: 0.0864
# Epoch 8/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9898 - loss: 0.0335 - val_accuracy: 0.9750 - val_loss: 0.0908
# Epoch 9/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9912 - loss: 0.0285 - val_accuracy: 0.9762 - val_loss: 0.0836
# Epoch 10/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9941 - loss: 0.0210 - val_accuracy: 0.9767 - val_loss: 0.0853
# Epoch 11/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9951 - loss: 0.0181 - val_accuracy: 0.9743 - val_loss: 0.0973
# Epoch 12/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9946 - loss: 0.0177 - val_accuracy: 0.9739 - val_loss: 0.0978
# Epoch 13/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9974 - loss: 0.0113 - val_accuracy: 0.9746 - val_loss: 0.0991
# Epoch 14/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9958 - loss: 0.0138 - val_accuracy: 0.9747 - val_loss: 0.1120
# Epoch 15/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9971 - loss: 0.0096 - val_accuracy: 0.9744 - val_loss: 0.1071
# Epoch 16/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9968 - loss: 0.0100 - val_accuracy: 0.9750 - val_loss: 0.1123
# Epoch 17/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9970 - loss: 0.0096 - val_accuracy: 0.9747 - val_loss: 0.1183
# Epoch 18/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9969 - loss: 0.0105 - val_accuracy: 0.9773 - val_loss: 0.1102
# Epoch 19/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9968 - loss: 0.0092 - val_accuracy: 0.9732 - val_loss: 0.1258
# Epoch 20/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9986 - loss: 0.0046 - val_accuracy: 0.9767 - val_loss: 0.1192

# %%
plt.figure(figsize=(10, 6))

plt.plot(history_sigmoid.history['val_accuracy'], label='Sigmoid')
plt.plot(history_tanh.history['val_accuracy'], label='Tanh')
plt.plot(history_relu.history['val_accuracy'], label='ReLU')

plt.title("Validation Accuracy Comparison")
plt.xlabel("Epoch")
plt.ylabel("Validation Accuracy")
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.plot(history_sigmoid.history['val_loss'], label='Sigmoid')
plt.plot(history_tanh.history['val_loss'], label='Tanh')
plt.plot(history_relu.history['val_loss'], label='ReLU')

plt.title("Validation Loss Comparison")
plt.xlabel("Epoch")
plt.ylabel("Validation Loss")
plt.legend()
plt.grid()
plt.show()

# %%
activation_results = {
    "Activation Function": ["Sigmoid", "Tanh", "ReLU"],
    "Final Training Accuracy": [
        history_sigmoid.history['accuracy'][-1],
        history_tanh.history['accuracy'][-1],
        history_relu.history['accuracy'][-1]
    ],
    "Final Validation Accuracy": [
        history_sigmoid.history['val_accuracy'][-1],
        history_tanh.history['val_accuracy'][-1],
        history_relu.history['val_accuracy'][-1]
    ],
    "Final Training Loss": [
        history_sigmoid.history['loss'][-1],
        history_tanh.history['loss'][-1],
        history_relu.history['loss'][-1]
    ],
    "Final Validation Loss": [
        history_sigmoid.history['val_loss'][-1],
        history_tanh.history['val_loss'][-1],
        history_relu.history['val_loss'][-1]
    ]
}

import pandas as pd

activation_results_df = pd.DataFrame(activation_results)
activation_results_df
# Out:
#   Activation Function  Final Training Accuracy  Final Validation Accuracy  \
# 0             Sigmoid                 0.996625                   0.974667
# 1                Tanh                 0.999687                   0.976333
# 2                ReLU                 0.998646                   0.976667
#
#    Final Training Loss  Final Validation Loss
# 0             0.017862               0.085096
# 1             0.002830               0.103063
# 2             0.004646               0.119232

# %%
#24BAD128 - VIBUSHA - PART C - EXP 2
print("24BAD128 - VIBUSHA - PART C - EXP 2")

def create_optimizer_model(optimizer):
    model = tf.keras.Sequential([
        tf.keras.layers.Input(shape=(784,)),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
    ])

    model.compile(
        optimizer=optimizer,
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    return model
# Out:
# 24BAD128 - VIBUSHA - PART C - EXP 2

# %%
sgd_model = create_optimizer_model(
    tf.keras.optimizers.SGD(learning_rate=0.01)
)

history_sgd = sgd_model.fit(
    x_train,
    y_train,
    epochs=20,
    batch_size=128,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6258 - loss: 1.3851 - val_accuracy: 0.8478 - val_loss: 0.6840
# Epoch 2/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8604 - loss: 0.5579 - val_accuracy: 0.8874 - val_loss: 0.4321
# Epoch 3/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8858 - loss: 0.4212 - val_accuracy: 0.9018 - val_loss: 0.3625
# Epoch 4/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8965 - loss: 0.3691 - val_accuracy: 0.9055 - val_loss: 0.3297
# Epoch 5/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9036 - loss: 0.3388 - val_accuracy: 0.9100 - val_loss: 0.3077
# Epoch 6/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9094 - loss: 0.3178 - val_accuracy: 0.9163 - val_loss: 0.2906
# Epoch 7/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9138 - loss: 0.3013 - val_accuracy: 0.9192 - val_loss: 0.2771
# Epoch 8/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9179 - loss: 0.2873 - val_accuracy: 0.9232 - val_loss: 0.2666
# Epoch 9/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9213 - loss: 0.2749 - val_accuracy: 0.9268 - val_loss: 0.2570
# Epoch 10/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9249 - loss: 0.2644 - val_accuracy: 0.9282 - val_loss: 0.2472
# Epoch 11/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9272 - loss: 0.2547 - val_accuracy: 0.9290 - val_loss: 0.2406
# Epoch 12/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9304 - loss: 0.2461 - val_accuracy: 0.9341 - val_loss: 0.2326
# Epoch 13/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9325 - loss: 0.2379 - val_accuracy: 0.9356 - val_loss: 0.2258
# Epoch 14/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9350 - loss: 0.2303 - val_accuracy: 0.9377 - val_loss: 0.2196
# Epoch 15/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9367 - loss: 0.2231 - val_accuracy: 0.9377 - val_loss: 0.2153
# Epoch 16/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9386 - loss: 0.2167 - val_accuracy: 0.9402 - val_loss: 0.2087
# Epoch 17/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9403 - loss: 0.2104 - val_accuracy: 0.9413 - val_loss: 0.2042
# Epoch 18/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9418 - loss: 0.2047 - val_accuracy: 0.9432 - val_loss: 0.2001
# Epoch 19/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9438 - loss: 0.1990 - val_accuracy: 0.9447 - val_loss: 0.1946
# Epoch 20/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9448 - loss: 0.1938 - val_accuracy: 0.9453 - val_loss: 0.1905

# %%
momentum_model = create_optimizer_model(
    tf.keras.optimizers.SGD(
        learning_rate=0.01,
        momentum=0.9
    )
)

history_momentum = momentum_model.fit(
    x_train,
    y_train,
    epochs=20,
    batch_size=128,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8424 - loss: 0.5595 - val_accuracy: 0.9222 - val_loss: 0.2711
# Epoch 2/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9305 - loss: 0.2450 - val_accuracy: 0.9399 - val_loss: 0.2116
# Epoch 3/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9456 - loss: 0.1881 - val_accuracy: 0.9508 - val_loss: 0.1714
# Epoch 4/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9556 - loss: 0.1520 - val_accuracy: 0.9591 - val_loss: 0.1427
# Epoch 5/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9627 - loss: 0.1282 - val_accuracy: 0.9616 - val_loss: 0.1318
# Epoch 6/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9682 - loss: 0.1097 - val_accuracy: 0.9668 - val_loss: 0.1181
# Epoch 7/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9720 - loss: 0.0953 - val_accuracy: 0.9675 - val_loss: 0.1121
# Epoch 8/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9764 - loss: 0.0834 - val_accuracy: 0.9666 - val_loss: 0.1126
# Epoch 9/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9788 - loss: 0.0740 - val_accuracy: 0.9707 - val_loss: 0.1024
# Epoch 10/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9812 - loss: 0.0652 - val_accuracy: 0.9710 - val_loss: 0.1009
# Epoch 11/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9834 - loss: 0.0578 - val_accuracy: 0.9726 - val_loss: 0.0963
# Epoch 12/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9854 - loss: 0.0519 - val_accuracy: 0.9728 - val_loss: 0.0946
# Epoch 13/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9873 - loss: 0.0466 - val_accuracy: 0.9716 - val_loss: 0.1001
# Epoch 14/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9886 - loss: 0.0418 - val_accuracy: 0.9737 - val_loss: 0.0921
# Epoch 15/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9897 - loss: 0.0387 - val_accuracy: 0.9736 - val_loss: 0.0906
# Epoch 16/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9910 - loss: 0.0338 - val_accuracy: 0.9742 - val_loss: 0.0910
# Epoch 17/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9924 - loss: 0.0300 - val_accuracy: 0.9754 - val_loss: 0.0904
# Epoch 18/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9929 - loss: 0.0274 - val_accuracy: 0.9748 - val_loss: 0.0896
# Epoch 19/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9936 - loss: 0.0248 - val_accuracy: 0.9763 - val_loss: 0.0899
# Epoch 20/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9950 - loss: 0.0227 - val_accuracy: 0.9737 - val_loss: 0.0943

# %%
rmsprop_model = create_optimizer_model(
    tf.keras.optimizers.RMSprop(learning_rate=0.001)
)

history_rmsprop = rmsprop_model.fit(
    x_train,
    y_train,
    epochs=20,
    batch_size=128,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8978 - loss: 0.3533 - val_accuracy: 0.9478 - val_loss: 0.1856
# Epoch 2/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9539 - loss: 0.1557 - val_accuracy: 0.9590 - val_loss: 0.1373
# Epoch 3/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9673 - loss: 0.1095 - val_accuracy: 0.9671 - val_loss: 0.1105
# Epoch 4/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9751 - loss: 0.0827 - val_accuracy: 0.9699 - val_loss: 0.1021
# Epoch 5/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9802 - loss: 0.0656 - val_accuracy: 0.9743 - val_loss: 0.0887
# Epoch 6/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9836 - loss: 0.0539 - val_accuracy: 0.9728 - val_loss: 0.0971
# Epoch 7/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9865 - loss: 0.0444 - val_accuracy: 0.9709 - val_loss: 0.0955
# Epoch 8/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9883 - loss: 0.0364 - val_accuracy: 0.9737 - val_loss: 0.0960
# Epoch 9/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9916 - loss: 0.0297 - val_accuracy: 0.9732 - val_loss: 0.1002
# Epoch 10/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9926 - loss: 0.0244 - val_accuracy: 0.9737 - val_loss: 0.1046
# Epoch 11/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9939 - loss: 0.0202 - val_accuracy: 0.9747 - val_loss: 0.1010
# Epoch 12/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9949 - loss: 0.0169 - val_accuracy: 0.9757 - val_loss: 0.1027
# Epoch 13/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9960 - loss: 0.0141 - val_accuracy: 0.9770 - val_loss: 0.0966
# Epoch 14/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9964 - loss: 0.0120 - val_accuracy: 0.9745 - val_loss: 0.1211
# Epoch 15/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9970 - loss: 0.0099 - val_accuracy: 0.9786 - val_loss: 0.1029
# Epoch 16/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9974 - loss: 0.0086 - val_accuracy: 0.9763 - val_loss: 0.1161
# Epoch 17/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9979 - loss: 0.0066 - val_accuracy: 0.9769 - val_loss: 0.1162
# Epoch 18/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9982 - loss: 0.0061 - val_accuracy: 0.9771 - val_loss: 0.1192
# Epoch 19/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9985 - loss: 0.0053 - val_accuracy: 0.9778 - val_loss: 0.1245
# Epoch 20/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9988 - loss: 0.0040 - val_accuracy: 0.9773 - val_loss: 0.1325

# %%
adam_model = create_optimizer_model(
    tf.keras.optimizers.Adam(learning_rate=0.001)
)

history_adam = adam_model.fit(
    x_train,
    y_train,
    epochs=20,
    batch_size=128,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8947 - loss: 0.3751 - val_accuracy: 0.9512 - val_loss: 0.1744
# Epoch 2/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9543 - loss: 0.1530 - val_accuracy: 0.9606 - val_loss: 0.1324
# Epoch 3/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9683 - loss: 0.1083 - val_accuracy: 0.9646 - val_loss: 0.1197
# Epoch 4/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9756 - loss: 0.0812 - val_accuracy: 0.9695 - val_loss: 0.1024
# Epoch 5/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9806 - loss: 0.0644 - val_accuracy: 0.9710 - val_loss: 0.1023
# Epoch 6/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9851 - loss: 0.0496 - val_accuracy: 0.9717 - val_loss: 0.0962
# Epoch 7/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9877 - loss: 0.0405 - val_accuracy: 0.9742 - val_loss: 0.0908
# Epoch 8/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9908 - loss: 0.0316 - val_accuracy: 0.9743 - val_loss: 0.0900
# Epoch 9/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9920 - loss: 0.0267 - val_accuracy: 0.9770 - val_loss: 0.0850
# Epoch 10/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9926 - loss: 0.0237 - val_accuracy: 0.9763 - val_loss: 0.0936
# Epoch 11/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9949 - loss: 0.0177 - val_accuracy: 0.9753 - val_loss: 0.0938
# Epoch 12/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9963 - loss: 0.0138 - val_accuracy: 0.9737 - val_loss: 0.1048
# Epoch 13/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9964 - loss: 0.0130 - val_accuracy: 0.9740 - val_loss: 0.1113
# Epoch 14/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9964 - loss: 0.0122 - val_accuracy: 0.9754 - val_loss: 0.1011
# Epoch 15/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9968 - loss: 0.0108 - val_accuracy: 0.9762 - val_loss: 0.1032
# Epoch 16/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9980 - loss: 0.0075 - val_accuracy: 0.9753 - val_loss: 0.1079
# Epoch 17/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9983 - loss: 0.0066 - val_accuracy: 0.9766 - val_loss: 0.1065
# Epoch 18/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9956 - loss: 0.0141 - val_accuracy: 0.9722 - val_loss: 0.1320
# Epoch 19/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9963 - loss: 0.0109 - val_accuracy: 0.9747 - val_loss: 0.1169
# Epoch 20/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9982 - loss: 0.0063 - val_accuracy: 0.9787 - val_loss: 0.1061

# %%
plt.figure(figsize=(10, 6))

plt.plot(history_sgd.history['val_loss'], label='SGD')
plt.plot(history_momentum.history['val_loss'], label='Momentum')
plt.plot(history_rmsprop.history['val_loss'], label='RMSProp')
plt.plot(history_adam.history['val_loss'], label='Adam')

plt.title("Validation Loss Comparison")
plt.xlabel("Epoch")
plt.ylabel("Validation Loss")
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.plot(history_sgd.history['val_accuracy'], label='SGD')
plt.plot(history_momentum.history['val_accuracy'], label='Momentum')
plt.plot(history_rmsprop.history['val_accuracy'], label='RMSProp')
plt.plot(history_adam.history['val_accuracy'], label='Adam')

plt.title("Validation Accuracy Comparison")
plt.xlabel("Epoch")
plt.ylabel("Validation Accuracy")
plt.legend()
plt.grid()
plt.show()

# %%
optimizer_results = {
    "Optimizer": ["SGD", "Momentum", "RMSProp", "Adam"],
    "Final Training Accuracy": [
        history_sgd.history['accuracy'][-1],
        history_momentum.history['accuracy'][-1],
        history_rmsprop.history['accuracy'][-1],
        history_adam.history['accuracy'][-1]
    ],
    "Final Validation Accuracy": [
        history_sgd.history['val_accuracy'][-1],
        history_momentum.history['val_accuracy'][-1],
        history_rmsprop.history['val_accuracy'][-1],
        history_adam.history['val_accuracy'][-1]
    ],
    "Final Training Loss": [
        history_sgd.history['loss'][-1],
        history_momentum.history['loss'][-1],
        history_rmsprop.history['loss'][-1],
        history_adam.history['loss'][-1]
    ],
    "Final Validation Loss": [
        history_sgd.history['val_loss'][-1],
        history_momentum.history['val_loss'][-1],
        history_rmsprop.history['val_loss'][-1],
        history_adam.history['val_loss'][-1]
    ]
}
optimizer_results_df = pd.DataFrame(optimizer_results)
optimizer_results_df
# Out:
#   Optimizer  Final Training Accuracy  Final Validation Accuracy  \
# 0       SGD                 0.944792                   0.945333
# 1  Momentum                 0.994958                   0.973667
# 2   RMSProp                 0.998833                   0.977333
# 3      Adam                 0.998187                   0.978750
#
#    Final Training Loss  Final Validation Loss
# 0             0.193809               0.190546
# 1             0.022746               0.094261
# 2             0.003971               0.132451
# 3             0.006280               0.106055

# %%
#24BAD128 - PART D - EXP 2
print("24BAD128 - PART D - EXP 2")

from google.colab import drive

drive.mount('/content/drive')
# Out:
# 24BAD128 - PART D - EXP 2
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

experiment_path = "/content/drive/MyDrive/ANN_Activation_Optimizer_Experiment"

os.makedirs(experiment_path, exist_ok=True)

print("Experiment folder created successfully.")
# Out:
# Experiment folder created successfully.

# %%
sigmoid_model.save(
    experiment_path + "/sigmoid_model.keras"
)
tanh_model.save(
    experiment_path + "/tanh_model.keras"
)
relu_model.save(
    experiment_path + "/relu_model.keras"
)
adam_model.save(
    experiment_path + "/adam_model.keras"
)
print("Models saved successfully.")
# Out:
# Models saved successfully.

# %%
activation_results_df.to_csv(
    experiment_path + "/activation_results.csv",
    index=False
)
optimizer_results_df.to_csv(
    experiment_path + "/optimizer_results.csv",
    index=False
)
print("Experiment results saved successfully.")
# Out:
# Experiment results saved successfully.
